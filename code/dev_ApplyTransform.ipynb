# %%
import ants
import matplotlib.pyplot as plt
import os
import re
cores=4

# %%
fmriprep_dir='../derivatives/fmriprep/'
tedana_dir='../derivatives/tedana/'

bold_imgs=[os.path.join(root,f) for root,dirs,files in os.walk(tedana_dir) for f in files if f.endswith('desc-optcom_bold.nii.gz')]

# %%
def auto_antstransform(img):
    sub='sub-'+re.search('/sub-(.*)/sub',img).group(1)
    task=re.search('task-(.*)_acq',img).group(1)
    acq=re.search('acq-(.*)_desc',img).group(1)
    print('Applying Transforms: \n',sub,'task: '+task,'acquisition: '+acq)

    output='%s/%s/func/%s_task-%s_acq-%s_desc-optcom-dewarped_bold.nii.gz'%(fmriprep_dir,sub,sub,task,acq)

    if not os.path.isfile(output):
        fixed = ants.image_read(
            '../masks/bg_image.nii') 
        moving = ants.image_read( 
            img)
        reg_bold2T1w='%s/%s/func/%s_task-%s_acq-%s_from-scanner_to-T1w_mode-image_xfm.txt'%(
            fmriprep_dir,sub,sub,task,acq)
        reg_t1w2MNI='%s/%s/anat/%s_from-T1w_to-MNI152NLin2009cAsym_mode-image_xfm.h5'%(
            fmriprep_dir,sub,sub)

        mywarpedimage = ants.apply_transforms( fixed=fixed, moving=moving,imagetype=3,
                                                   transformlist=[reg_bold2T1w,reg_t1w2MNI] )
        mywarpedimage.to_filename(output)
    else:
        print(output+' already exists please remove if this nees to be re-run')

# %%
from multiprocessing import Pool

pool = Pool(cores)
results = pool.map(auto_antstransform, bold_imgs)
# Out:
# Working:
# Working:
# Working:
# Working:
#     sub-10154sub-10203sub-10137sub-10142    task: sharedrewardtask: sharedrewardtask: sharedrewardtask: sharedreward    acquisition: mb1me4acquisition: mb3me4acquisition: mb1me4acquisition: mb1me4
#
#
#
# Working:
#  sub-10154 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10137 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10142 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10203 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10108 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10137 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10154 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10108 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10142 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10223 task: sharedreward acquisition: mb6me4
# Working:
#  sub-12042 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10108 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10041 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10085 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10041 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10223 task: sharedreward acquisition: mb3me4
# Working:
#  sub-12042 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10203 task: sharedreward acquisition: mb6me4
# Working:
#  sub-12042 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10041 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10085 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10085 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10186 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10186 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10198 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10074 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10043 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10188 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10043 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10188 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10069 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10035 task: sharedreward acquisition: mb1me4
# ../derivatives/fmriprep//sub-10035/func/sub-10035_task-sharedreward_acq-mb1me4_desc-optcom-dewarped_bold.nii.gz already exists please remove if this nees to be re-run
# Working:
#  sub-10035 task: sharedreward acquisition: mb6me4
# ../derivatives/fmriprep//sub-10035/func/sub-10035_task-sharedreward_acq-mb6me4_desc-optcom-dewarped_bold.nii.gz already exists please remove if this nees to be re-run
# Working:
#  sub-10035 task: sharedreward acquisition: mb3me4
# ../derivatives/fmriprep//sub-10035/func/sub-10035_task-sharedreward_acq-mb3me4_desc-optcom-dewarped_bold.nii.gz already exists please remove if this nees to be re-run
# Working:
#  sub-10198 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10074 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10059 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10234 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10069 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10188 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10234 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10234 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10186 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10043 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10059 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10136 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10136 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10069 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10059 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10303 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10080 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10078 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10136 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10221 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10221 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10080 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10221 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10017 task: sharedreward acquisition: mb6me4
# ../derivatives/fmriprep//sub-10017/func/sub-10017_task-sharedreward_acq-mb6me4_desc-optcom-dewarped_bold.nii.gz already exists please remove if this nees to be re-run
# Working:
#  sub-10017 task: sharedreward acquisition: mb3me4
# ../derivatives/fmriprep//sub-10017/func/sub-10017_task-sharedreward_acq-mb3me4_desc-optcom-dewarped_bold.nii.gz already exists please remove if this nees to be re-run
# Working:
#  sub-10017 task: sharedreward acquisition: mb1me4
# ../derivatives/fmriprep//sub-10017/func/sub-10017_task-sharedreward_acq-mb1me4_desc-optcom-dewarped_bold.nii.gz already exists please remove if this nees to be re-run
# Working:
#  sub-10054 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10078 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10080 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10078 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10094 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10024 task: sharedreward acquisition: mb1me4
# ../derivatives/fmriprep//sub-10024/func/sub-10024_task-sharedreward_acq-mb1me4_desc-optcom-dewarped_bold.nii.gz already exists please remove if this nees to be re-run
# Working:
#  sub-10024 task: sharedreward acquisition: mb6me4
# ../derivatives/fmriprep//sub-10024/func/sub-10024_task-sharedreward_acq-mb6me4_desc-optcom-dewarped_bold.nii.gz already exists please remove if this nees to be re-run
# Working:
#  sub-10024  task: sharedrewardacquisition: mb3me4
# ../derivatives/fmriprep//sub-10024/func/sub-10024_task-sharedreward_acq-mb3me4_desc-optcom-dewarped_bold.nii.gz already exists please remove if this nees to be re-run
# Working:
#  sub-10035retest task: sharedreward acquisition: mb3me4
# Working:
#  sub-10094 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10130 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10054 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10130 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10035retest task: sharedreward acquisition: mb6me4
# Working:
#  sub-10094 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10054 task: sharedreward acquisition: mb1me4
# Working:
#  sub-10130 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10125 task: sharedreward acquisition: mb3me4
# Working:
#  sub-10035retest task: sharedreward acquisition: mb1me4
# Working:
#  sub-10125 task: sharedreward acquisition: mb6me4
# Working:
#  sub-10125 task: sharedreward acquisition: mb1me4
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "<ipython-input-3-39a581cb4df5>", line 19, in auto_antstransform
#     mywarpedimage = ants.apply_transforms( fixed=fixed, moving=moving,imagetype=3,
#   File "/opt/anaconda3/lib/python3.8/site-packages/ants/registration/apply_transforms.py", line 109, in apply_transforms
#     raise Exception('Transform %s does not exist' % tl_path)
# Exception: Transform ../derivatives/fmriprep//sub-10198/func/sub-10198_task-sharedreward_acq-mb3me4_from-scanner_to-T1w_mode-image_xfm.txt does not exist
# """
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-7c8df380218a> in <module>
#       2
#       3 pool = Pool(cores)
# ----> 4 results = pool.map(auto_antstransform, bold_imgs)
#
# /opt/anaconda3/lib/python3.8/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     362         in a list that is returned.
#     363         '''
# --> 364         return self._map_async(func, iterable, mapstar, chunksize).get()
#     365
#     366     def starmap(self, func, iterable, chunksize=None):
#
# /opt/anaconda3/lib/python3.8/multiprocessing/pool.py in get(self, timeout)
#     769             return self._value
#     770         else:
# --> 771             raise self._value
#     772
#     773     def _set(self, i, obj):
#
# Exception: Transform ../derivatives/fmriprep//sub-10198/func/sub-10198_task-sharedreward_acq-mb3me4_from-scanner_to-T1w_mode-image_xfm.txt does not exist

# %%
import os
import pandas as pd
from natsort import natsorted
import re
import numpy as np

# %%
metric_files = natsorted([os.path.join(root,f) for root,dirs,files in os.walk(
    '../derivatives/tedana/') for f in files if f.endswith("PCA_metrics.tsv")])
subs=set([re.search("tedana/(.*)/sub-",file).group(1) for file in metric_files])
for sub in subs:
    print(sub,"has %s acqs of denoised tedana"%(sum(sub in s for s in metric_files)))
for file in metric_files:
    #Read in the directory, sub-number, and acquisition
    base=re.search("(.*)PCA_metrics",file).group(1)
    sub=re.search("tedana/(.*)/sub-",file).group(1)
    acq=re.search("acq-(.*)_desc",file).group(1)
    #print(sub,acq)
    
    #import the data as dataframes
    fmriprep_fname="../derivatives/fmriprep/%s/func/%s_task-sharedreward_acq-%s_desc-confounds_timeseries.tsv"%(sub,sub,acq)
    if os.path.exists(fmriprep_fname):
        print("Making Counfounds: %s %s"%(sub,acq))
        fmriprep_confounds=pd.read_csv(fmriprep_fname,sep='\t')
        PCA_mixing=pd.read_csv('%sPCA_mixing.tsv'%(base),sep='\t')
        PCA_metrics=pd.read_csv('%sPCA_metrics.tsv'%(base),sep='\t')
        ICA_mixing=pd.read_csv('%sICA_mixing.tsv'%(base),sep='\t')
        ICA_metrics=pd.read_csv('%stedana_metrics.tsv'%(base),sep='\t')
        # Select columns from each data frame for final counfounds file
        ICA_mixing=ICA_mixing[ICA_metrics[ICA_metrics['classification']=='rejected']['Component']]
        PCA_mixing=PCA_mixing[PCA_metrics[PCA_metrics['classification']=='rejected']['Component']]

        cosine = [col for col in fmriprep_confounds if col.startswith('cosine')]
        NSS = [col for col in fmriprep_confounds if col.startswith('non_steady_state')]
        motion = ['trans_x','trans_y','trans_z','rot_x','rot_y','rot_z']
        fd = ['framewise_displacement']
        filter_col=np.concatenate([cosine,NSS,motion,fd])
        fmriprep_confounds=fmriprep_confounds[filter_col]

        #Combine horizontally
        Comp_confounds=pd.concat([ICA_mixing, PCA_mixing], axis=1)
        confounds_df=pd.concat([fmriprep_confounds, Comp_confounds], axis=1)
        #Output in fsl-friendly format
        outfname='../derivatives/fsl/confounds/%s/%s_task-sharedreward_acq-%s_desc-TedanaPlusConfounds.tsv'%(sub,sub,acq)
        confounds_df.to_csv(outfname,index=False,header=False,sep='\t')
    else:
        print("fmriprep failed for %s %s"%(sub,acq))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1e4ba0b32bf4> in <module>
# ----> 1 metric_files = natsorted([os.path.join(root,f) for root,dirs,files in os.walk(
#       2     '../derivatives/tedana/') for f in files if f.endswith("PCA_metrics.tsv")])
#       3 subs=set([re.search("tedana/(.*)/sub-",file).group(1) for file in metric_files])
#       4 for sub in subs:
#       5     print(sub,"has %s acqs of denoised tedana"%(sum(sub in s for s in metric_files)))
#
# NameError: name 'natsorted' is not defined
